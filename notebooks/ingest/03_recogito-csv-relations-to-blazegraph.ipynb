# %%
from rdflib import Dataset, URIRef
from rdflib import Namespace
import csv

# %%
CRM = Namespace('http://cidoc-crm.org/cidoc-crm/')

# %%
# the URI for our named graph that will contain our data
anno_named_graph_uri = 'http://example.org/ns/users/robcast/genesis-example'
anno_named_graph_uriref = URIRef(anno_named_graph_uri)

# %%
# open a connection to the Blazegraph triple store
blazegraph_uri = 'http://localhost:8080/blazegraph/namespace/kb/sparql'
store = Dataset('SPARQLUpdateStore')
store.open((blazegraph_uri, blazegraph_uri))

# %%
# find our named graph if it exists or create a new one
anno_named_graph = None
for g in store.graphs():
    if g.identifier == anno_named_graph_uriref:
        anno_named_graph = g

if anno_named_graph is None:
    anno_named_graph = store.graph(anno_named_graph_uriref)

# %%
# read relations from CSV file
with open('recogito-genesis-relations.csv', newline='') as csvfile:
    csvreader = csv.DictReader(csvfile)
    for row in csvreader:
        source_name = row['source']
        target_name = row['target']
        rel_type = row['relation']
        print(f"relation: {source_name} - {rel_type} -> {target_name}")
        
        if rel_type == 'father_of':
            source_person = URIRef(f"{anno_named_graph_uri}/persons/{source_name}")
            target_person = URIRef(f"{anno_named_graph_uri}/persons/{target_name}")
            # create father_of as crm:P152_has_parent relation
            anno_named_graph.add((target_person, CRM.P152_has_parent, source_person))
        elif rel_type == 'river_in':
            source_person = URIRef(f"{anno_named_graph_uri}/rivers/{source_name}")
            target_person = URIRef(f"{anno_named_graph_uri}/places/{target_name}")
            # create father_of as crm:P152_has_parent relation
            anno_named_graph.add((target_person, CRM.P53_has_location, source_person))
            
            # we could add a relation linked to the concrete annotations in the source
            #source_id = row['source_id']
            #target_id = row['target_id']
            #target_anno = URIRef(f"https://recogito.pelagios.org/annotation/{target_id}")
            #source_anno = URIRef(f"https://recogito.pelagios.org/annotation/{source_id}")
            
        else:
            print(f"don't know what to do with {rel_type=}")
            pass
# Out:
# relation: Adam - is father of -> Seth
# don't know what to do with rel_type='is father of'
# relation: Enosh - is father of -> Kenan
# don't know what to do with rel_type='is father of'
# relation: Cush - is father of -> Havilah
# don't know what to do with rel_type='is father of'
# relation: Cush - is father of -> Sabtah
# don't know what to do with rel_type='is father of'
# relation: Cush - is father of -> Raamah
# don't know what to do with rel_type='is father of'
# relation: Cush - is father of -> Sabteca
# don't know what to do with rel_type='is father of'
# relation: Cush - is father of -> Seba
# don't know what to do with rel_type='is father of'
# relation: Cush - is father of -> Nimrod
# don't know what to do with rel_type='is father of'
# relation: Ham - is father of -> Cush
# don't know what to do with rel_type='is father of'
# relation: Ham - is father of -> Mizraim
# don't know what to do with rel_type='is father of'
# relation: Ham - is father of -> Put
# don't know what to do with rel_type='is father of'
# relation: Ham - is father of -> Canaan
# don't know what to do with rel_type='is father of'
# relation: Aram - is father of -> Uz
# don't know what to do with rel_type='is father of'
# relation: Aram - is father of -> Hul
# don't know what to do with rel_type='is father of'
# relation: Aram - is father of -> Gether
# don't know what to do with rel_type='is father of'
# relation: Aram - is father of -> Mash
# don't know what to do with rel_type='is father of'
# relation: Lamech - is father of -> Jabal
# don't know what to do with rel_type='is father of'
# relation: Lamech - is father of -> Jubal
# don't know what to do with rel_type='is father of'
# relation: Lamech - is father of -> Tubal Cain
# don't know what to do with rel_type='is father of'
# relation: Lamech - is father of -> Naamah
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Almodad
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Sheleph
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Hazarmaveth
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Jerah
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Hadoram
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Uzal
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Diklah
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Obal
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Abimael
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Sheba
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Ophir
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Havilah
# don't know what to do with rel_type='is father of'
# relation: Joktan - is father of -> Jobab
# don't know what to do with rel_type='is father of'
# relation: Noah - is father of -> Shem
# don't know what to do with rel_type='is father of'
# relation: Noah - is father of -> Ham
# don't know what to do with rel_type='is father of'
# relation: Noah - is father of -> Japheth
# don't know what to do with rel_type='is father of'
# relation: Arpachshad - is father of -> Shelah
# don't know what to do with rel_type='is father of'
# relation: Mahalalel - is father of -> Jared
# don't know what to do with rel_type='is father of'
# relation: Kenan - is father of -> Mahalalel
# don't know what to do with rel_type='is father of'
# relation: Seth - is father of -> Enosh
# don't know what to do with rel_type='is father of'
# relation: Mizraim - is father of -> Ludim
# don't know what to do with rel_type='is father of'
# relation: Mizraim - is father of -> Anamim
# don't know what to do with rel_type='is father of'
# relation: Mizraim - is father of -> Lehabim
# don't know what to do with rel_type='is father of'
# relation: Mizraim - is father of -> Naphtuhim
# don't know what to do with rel_type='is father of'
# relation: Mizraim - is father of -> Pathrusim
# don't know what to do with rel_type='is father of'
# relation: Mizraim - is father of -> Casluhim
# don't know what to do with rel_type='is father of'
# relation: Mizraim - is father of -> Caphtorim
# don't know what to do with rel_type='is father of'
# relation: Irad - is father of -> Mehujael
# don't know what to do with rel_type='is father of'
# relation: Enoch - is father of -> Irad
# don't know what to do with rel_type='is father of'
# relation: Japheth - is father of -> Gomer
# don't know what to do with rel_type='is father of'
# relation: Japheth - is father of -> Magog
# don't know what to do with rel_type='is father of'
# relation: Japheth - is father of -> Madai
# don't know what to do with rel_type='is father of'
# relation: Japheth - is father of -> Javan
# don't know what to do with rel_type='is father of'
# relation: Japheth - is father of -> Tubal
# don't know what to do with rel_type='is father of'
# relation: Japheth - is father of -> Tiras
# don't know what to do with rel_type='is father of'
# relation: Meshech - is father of -> Japheth
# don't know what to do with rel_type='is father of'
# relation: Shelah - is father of -> Eber
# don't know what to do with rel_type='is father of'
# relation: Seth - is father of -> Enosh
# don't know what to do with rel_type='is father of'
# relation: Lamech - is father of -> Noah
# don't know what to do with rel_type='is father of'
# relation: Methuselah - is father of -> Lamech
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Sidon
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Heth
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Jebusite
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Amorite
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Girgashite
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Hivite
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Arkite
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Sinite
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Arvadite
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Zemarite
# don't know what to do with rel_type='is father of'
# relation: Canaan - is father of -> Hamathite
# don't know what to do with rel_type='is father of'
# relation: Jared - is father of -> Enoch
# don't know what to do with rel_type='is father of'
# relation: Mehujael - is father of -> Methushael
# don't know what to do with rel_type='is father of'
# relation: Cain - is father of -> Enoch
# don't know what to do with rel_type='is father of'
# relation: Raamah - is father of -> Sheba
# don't know what to do with rel_type='is father of'
# relation: Raamah - is father of -> Dedan
# don't know what to do with rel_type='is father of'
# relation: Adam - is father of -> Cain
# don't know what to do with rel_type='is father of'
# relation: Adam - is father of -> Abel
# don't know what to do with rel_type='is father of'
# relation: Gomer - is father of -> Ashkenaz
# don't know what to do with rel_type='is father of'
# relation: Gomer - is father of -> Riphath
# don't know what to do with rel_type='is father of'
# relation: Gomer - is father of -> Togarmah
# don't know what to do with rel_type='is father of'
# relation: Javan - is father of -> Elishah
# don't know what to do with rel_type='is father of'
# relation: Javan - is father of -> Tarshish
# don't know what to do with rel_type='is father of'
# relation: Javan - is father of -> Kittim
# don't know what to do with rel_type='is father of'
# relation: Javan - is father of -> Dodanim
# don't know what to do with rel_type='is father of'
# relation: Shem - is father of -> Elam
# don't know what to do with rel_type='is father of'
# relation: Shem - is father of -> Asshur
# don't know what to do with rel_type='is father of'
# relation: Shem - is father of -> Arpachshad
# don't know what to do with rel_type='is father of'
# relation: Shem - is father of -> Lud
# don't know what to do with rel_type='is father of'
# relation: Shem - is father of -> Aram
# don't know what to do with rel_type='is father of'
# relation: Enoch - is father of -> Methuselah
# don't know what to do with rel_type='is father of'
# relation: Methushael - is father of -> Lamech
# don't know what to do with rel_type='is father of'
# relation: Ham - is father of -> Canaan
# don't know what to do with rel_type='is father of'
# relation: Eber - is father of -> Peleg
# don't know what to do with rel_type='is father of'
# relation: Eber - is father of -> Joktan
# don't know what to do with rel_type='is father of'

# %%
store.close()
